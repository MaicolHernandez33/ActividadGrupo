# %%
# 1. Cargar la extensión de Kedro
# %load_ext kedro.ipython

# 2. Ahora sí, inicializar el proyecto
# %reload_kedro
# Out:
# [03/23/26 22:11:37] INFO     Using                                                                  ]8;id=801544;file://C:\Users\maico\analisisdatoskedro\kedro_env\lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=497874;file://C:\Users\maico\analisisdatoskedro\kedro_env\lib\site-packages\kedro\framework\project\__init__.py#269\269]8;;\
#                              'C:\Users\maico\analisisdatoskedro\kedro_env\lib\site-packages\kedro\f
#                              ramework\project\rich_logging.yml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=288206;file://C:\Users\maico\analisisdatoskedro\kedro_env\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=686181;file://C:\Users\maico\analisisdatoskedro\kedro_env\lib\site-packages\kedro\ipython\__init__.py#64\64]8;;\
# ...

# %%
df = catalog.load("players_all")
df.tail()
# Out:
# [03/23/26 22:12:43] INFO     Loading data from players_all (ParquetDataset)...                 ]8;id=300628;file://C:\Users\maico\analisisdatoskedro\kedro_env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=870996;file://C:\Users\maico\analisisdatoskedro\kedro_env\lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         sofifa_id                                         player_url  \
# 100990     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 100991     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 100992     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 100993     251110  https://sofifa.com/player/251110/haijian-wang/...
# 100994     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#           short_name     long_name  age         dob  height_cm  weight_kg  \
# ...

# %%
columnas_interes = ['short_name', 'long_name', 'age', 'height_cm', 'weight_kg', 'nationality']
messi_data = df[df['long_name'].str.contains("Messi", case=False, na=False)]

# Mostrar los resultados
messi_data[columnas_interes]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              short_name                       long_name  age  height_cm  \
# 0              L. Messi  Lionel Andrés Messi Cuccittini   27        169
# 8098            Leandro      Leandro Messias dos Santos   30        183
# 15465          L. Messi  Lionel Andrés Messi Cuccittini   28        170
# 26291           Leandro      Leandro Messias dos Santos   31        183
# 29064  J. Messi Enguene            Junior Messi Enguene   21        176
# 30347          L. Messi  Lionel Andrés Messi Cuccittini   29        170
# 38090          Fabrício     Fabrício dos Santos Messias   26        182
# 39635           Leandro      Leandro Messias dos Santos   32        183
# 45098      N. Messiniti               Nicolás Messiniti   20        184
# 47356          L. Messi  Lionel Andrés Messi Cuccittini   30        170
# ...

# %%
print(df.columns.tolist())
# Out:
# ['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club', 'overall', 'potential', 'value_eur', 'wage_eur', 'player_positions', 'preferred_foot', 'international_reputation', 'weak_foot', 'skill_moves', 'work_rate', 'body_type', 'real_face', 'release_clause_eur', 'player_tags', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'contract_valid_until', 'nation_position', 'nation_jersey_number', 'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'player_traits', 'attacking_crossing', 'attacking_finishing', 'attacking_heading_accuracy', 'attacking_short_passing', 'attacking_volleys', 'skill_dribbling', 'skill_curve', 'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed', 'movement_agility', 'movement_reactions', 'movement_balance', 'power_shot_power', 'powe
# ...
